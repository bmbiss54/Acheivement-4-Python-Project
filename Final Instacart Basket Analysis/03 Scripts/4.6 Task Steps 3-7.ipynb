# %% [markdown]
# #### Contents

# %% [markdown]
# #### Merging df_ords and df_prods

# %% [markdown]
# #### Dropping Unnessary Columns from df_ords_prods

# %% [markdown]
# # Importing Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Importing Dataframes

# %%
# Making Path do data as a string
path = r'C:\Users\bbissonette\Documents\Data Analytics Course\Acheivement 4\Instacart Basket Analysis'

# %%
# Importing Prods df
df_prods = pd.read_csv(os.path.join(path,'02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %%
# Importing Ords Merged Large df
df_ords_prods_combined = pd.read_pickle(os.path.join(path,'02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %% [markdown]
# # Checking Shape of the Merged df

# %%
# Checking shape of df ords prods combined
df_ords_prods_combined.shape
# Out:
# (32434489, 13)

# %%
# Checking view of df ords prods combined
df_ords_prods_combined.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0             0           0   2539329        1    prior             1
# 1             0           0   2539329        1    prior             1
# 2             0           0   2539329        1    prior             1
# 3             0           0   2539329        1    prior             1
# 4             0           0   2539329        1    prior             1
#
#    orders_day_of_week  order_hour  days_since_prior_order  product_id  \
# 0                   2           8                     NaN         196
# 1                   2           8                     NaN       14084
# 2                   2           8                     NaN       12427
# 3                   2           8                     NaN       26088
# 4                   2           8                     NaN       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# ...

# %%
# Checking df prods shape
df_prods.shape
# Out:
# (49688, 6)

# %%
# Check view of df prods
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# Have to remove _Merge Column due to error "Cannot use name of an existing column for indicator column" Error
df_ords_prods_combined = df_ords_prods_combined.drop(columns = ['_merge'])

# %%
# Merging the two df's on the 
df_ords_prods_merged = df_ords_prods_combined.merge(df_prods, on = 'product_id', indicator = True)

# %%
# Checking merged df shape
df_ords_prods_merged.shape
# Out:
# (32433030, 18)

# %%
# Checking merged df table layout
df_ords_prods_merged.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0             0             0   2539329        1    prior             1
# 1             1             1   2398795        1    prior             2
# 2             2             2    473747        1    prior             3
# 3             3             3   2254736        1    prior             4
# 4             4             4    431534        1    prior             5
#
#    orders_day_of_week  order_hour  days_since_prior_order  product_id  \
# 0                   2           8                     NaN         196
# 1                   3           7                    15.0         196
# 2                   3          12                    21.0         196
# 3                   4           7                    29.0         196
# 4                   4          15                    28.0         196
#
#    add_to_cart_order  reordered  Unnamed: 0_y product_name  aisle_id  \
# ...

# %% [markdown]
# ### Removing Unnamed columns for simplicity

# %%
# Dropping redundant columns
df_ords_prods_merged = df_ords_prods_merged.drop(columns = ['Unnamed: 0.1','Unnamed: 0_x'])

# %%
# Checking new shape after dropped columns
df_ords_prods_merged.shape
# Out:
# (32433030, 16)

# %%
# Checking New Layout of table after dropped columns
df_ords_prods_merged.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  order_hour  \
# 0   2539329        1    prior             1                   2           8
# 1   2398795        1    prior             2                   3           7
# 2    473747        1    prior             3                   3          12
# 3   2254736        1    prior             4                   4           7
# 4    431534        1    prior             5                   4          15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#    Unnamed: 0_y product_name  aisle_id  department_id  prices _merge
# ...

# %% [markdown]
# # Exporting Merged DF into Pickle File

# %%
# Exporting Merged df to pickle file
df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
